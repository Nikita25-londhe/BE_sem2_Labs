# %%
# !pip3 install pandas
# !pip3 install numpy
# !pip3 install matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in ./Library/Python/3.9/lib/python/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.22.4 in ./Library/Python/3.9/lib/python/site-packages (from pandas) (2.0.2)
# Requirement already satisfied: pytz>=2020.1 in ./Library/Python/3.9/lib/python/site-packages (from pandas) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in ./Library/Python/3.9/lib/python/site-packages (from pandas) (2026.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./Library/Python/3.9/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in ./Library/Python/3.9/lib/python/site-packages (2.0.2)
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Using cached matplotlib-3.9.4-cp39-cp39-macosx_11_0_arm64.whl (7.8 MB)
# Collecting pillow>=8
#   Using cached pillow-11.3.0-cp39-cp39-macosx_11_0_arm64.whl (4.7 MB)
# Requirement already satisfied: numpy>=1.23 in ./Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.0.2)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.60.2-cp39-cp39-macosx_10_9_universal2.whl (2.9 MB)
# Collecting importlib-resources>=3.2.0
#   Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.4.7-cp39-cp39-macosx_11_0_arm64.whl (64 kB)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.3.0-cp39-cp39-macosx_11_0_arm64.whl (249 kB)
# Requirement already satisfied: python-dateutil>=2.7 in ./Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: packaging>=20.0 in ./Library/Python/3.9/lib/python/site-packages (from matplotlib) (26.2)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: zipp>=3.1.0 in ./Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.1)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
#   WARNING: The scripts fonttools, pyftmerge, pyftsubset and ttx are installed in '/Users/nikitalondhe/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.60.2 importlib-resources-6.5.2 kiwisolver-1.4.7 matplotlib-3.9.4 pillow-11.3.0 pyparsing-3.3.2
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
df=pd.read_csv("/Users/nikitalondhe/Documents/HousingData.csv")
df.head(5)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
# !pip3 install seaborn
import seaborn as sns
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in ./Library/Python/3.9/lib/python/site-packages (from seaborn) (3.9.4)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in ./Library/Python/3.9/lib/python/site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in ./Library/Python/3.9/lib/python/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: pillow>=8 in ./Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in ./Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: packaging>=20.0 in ./Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in ./Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.5.2)
# Requirement already satisfied: fonttools>=4.22.0 in ./Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.2)
# Requirement already satisfied: zipp>=3.1.0 in ./Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.23.1)
# Requirement already satisfied: tzdata>=2022.7 in ./Library/Python/3.9/lib/python/site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: pytz>=2020.1 in ./Library/Python/3.9/lib/python/site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.15.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
plt.figure(figsize=(15,6))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df.isna().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df.shape
# Out:
# (506, 14)

# %%
df.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
df.fillna(df.mean(),inplace=True)

# %%
df.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
x=df.drop('MEDV',axis=1)

# %%
y=df['MEDV']

# %%
# !pip3 install StandardScaler
from sklearn.preprocessing import StandardScaler
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting StandardScaler
#   Downloading StandardScaler-0.5.tar.gz (2.4 kB)
# Requirement already satisfied: numpy in ./Library/Python/3.9/lib/python/site-packages (from StandardScaler) (2.0.2)
# Requirement already satisfied: pandas in ./Library/Python/3.9/lib/python/site-packages (from StandardScaler) (2.3.3)
# Collecting scikit-learn
#   Using cached scikit_learn-1.6.1-cp39-cp39-macosx_12_0_arm64.whl (11.1 MB)
# Collecting scikit-elm
#   Downloading scikit_elm-0.21a0-py3-none-any.whl (30 kB)
# Collecting dask
#   Downloading dask-2024.8.0-py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 6.9 MB/s eta 0:00:01
# Requirement already satisfied: importlib-metadata>=4.13.0 in ./Library/Python/3.9/lib/python/site-packages (from dask->StandardScaler) (8.7.1)
# Collecting partd>=1.4.0
#   Downloading partd-1.4.2-py3-none-any.whl (18 kB)
# Requirement already satisfied: pyyaml>=5.3.1 in ./Library/Python/3.9/lib/python/site-packages (from dask->StandardScaler) (6.0.3)
# Collecting cloudpickle>=1.5.0
#   Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Collecting click>=8.1
#   Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Collecting fsspec>=2021.09.0
#   Downloading fsspec-2025.10.0-py3-none-any.whl (200 kB)
#      |████████████████████████████████| 200 kB 65.3 MB/s eta 0:00:01
# Collecting toolz>=0.10.0
#   Downloading toolz-1.1.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 17.3 MB/s eta 0:00:01
# Requirement already satisfied: packaging>=20.0 in ./Library/Python/3.9/lib/python/site-packages (from dask->StandardScaler) (26.2)
# Requirement already satisfied: zipp>=3.20 in ./Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.13.0->dask->StandardScaler) (3.23.1)
# Collecting locket
#   Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./Library/Python/3.9/lib/python/site-packages (from pandas->StandardScaler) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./Library/Python/3.9/lib/python/site-packages (from pandas->StandardScaler) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in ./Library/Python/3.9/lib/python/site-packages (from pandas->StandardScaler) (2026.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->StandardScaler) (1.15.0)
# Collecting scipy
#   Using cached scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl (30.3 MB)
# Collecting threadpoolctl>=3.1.0
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting joblib>=1.2.0
#   Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Building wheels for collected packages: StandardScaler
#   Building wheel for StandardScaler (setup.py) ... done
#   Created wheel for StandardScaler: filename=StandardScaler-0.5-py3-none-any.whl size=2613 sha256=13cce69150c9249d5935dfaf8b3b2f47f789c416cf5210f5d79a1cdb116737a1
#   Stored in directory: /Users/nikitalondhe/Library/Caches/pip/wheels/98/7d/ec/7ea52e96c7cf25f808c75a53cb1db1ef8e7c071debbc983276
# Successfully built StandardScaler
# Installing collected packages: toolz, threadpoolctl, scipy, locket, joblib, scikit-learn, partd, fsspec, cloudpickle, click, scikit-elm, dask, StandardScaler
#   WARNING: The script dask is installed in '/Users/nikitalondhe/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed StandardScaler-0.5 click-8.1.8 cloudpickle-3.1.2 dask-2024.8.0 fsspec-2025.10.0 joblib-1.5.3 locket-1.0.0 partd-1.4.2 scikit-elm-0.21a0 scikit-learn-1.6.1 scipy-1.13.1 threadpoolctl-3.6.0 toolz-1.1.0
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
# !pip3 install tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow
#   Using cached tensorflow-2.20.0-cp39-cp39-macosx_12_0_arm64.whl (200.4 MB)
# Requirement already satisfied: numpy>=1.26.0 in ./Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: requests<3,>=2.21.0 in ./Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.32.5)
# Collecting ml_dtypes<1.0.0,>=0.5.1
#   Using cached ml_dtypes-0.5.4-cp39-cp39-macosx_10_9_universal2.whl (676 kB)
# Requirement already satisfied: packaging in ./Library/Python/3.9/lib/python/site-packages (from tensorflow) (26.2)
# Collecting h5py>=3.11.0
#   Using cached h5py-3.14.0-cp39-cp39-macosx_11_0_arm64.whl (2.8 MB)
# Collecting grpcio<2.0,>=1.24.3
#   Using cached grpcio-1.80.0-cp39-cp39-macosx_11_0_universal2.whl (12.0 MB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting opt_einsum>=2.3.2
#   Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Collecting flatbuffers>=24.3.25
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Collecting keras>=3.10.0
#   Using cached keras-3.10.0-py3-none-any.whl (1.4 MB)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-2.3.1-py3-none-any.whl (135 kB)
# Collecting tensorboard~=2.20.0
#   Using cached tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow) (58.0.4)
# Collecting google_pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in ./Library/Python/3.9/lib/python/site-packages (from tensorflow) (4.15.0)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Using cached gast-0.7.0-py3-none-any.whl (22 kB)
# Collecting libclang>=13.0.0
#   Using cached libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl (25.8 MB)
# Collecting protobuf>=5.28.0
#   Using cached protobuf-6.33.6-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
# Collecting wrapt>=1.11.0
#   Using cached wrapt-2.1.2-cp39-cp39-macosx_11_0_arm64.whl (61 kB)
# Requirement already satisfied: six>=1.12.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Collecting rich
#   Using cached rich-15.0.0-py3-none-any.whl (310 kB)
# Collecting namex
#   Using cached namex-0.1.0-py3-none-any.whl (5.9 kB)
# Collecting optree
#   Downloading optree-0.19.1-cp39-cp39-macosx_11_0_arm64.whl (370 kB)
#      |████████████████████████████████| 370 kB 6.4 MB/s eta 0:00:01
# Requirement already satisfied: charset_normalizer<4,>=2 in ./Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (2026.4.22)
# Requirement already satisfied: idna<4,>=2.5 in ./Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (3.13)
# Collecting markdown>=2.6.8
#   Using cached markdown-3.9-py3-none-any.whl (107 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: pillow in ./Library/Python/3.9/lib/python/site-packages (from tensorboard~=2.20.0->tensorflow) (11.3.0)
# Collecting werkzeug>=1.0.1
#   Using cached werkzeug-3.1.8-py3-none-any.whl (226 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in ./Library/Python/3.9/lib/python/site-packages (from markdown>=2.6.8->tensorboard~=2.20.0->tensorflow) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in ./Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.20.0->tensorflow) (3.23.1)
# Requirement already satisfied: markupsafe>=2.1.1 in ./Library/Python/3.9/lib/python/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./Library/Python/3.9/lib/python/site-packages (from rich->keras>=3.10.0->tensorflow) (2.20.0)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: mdurl, markdown-it-py, werkzeug, tensorboard-data-server, rich, protobuf, optree, namex, ml-dtypes, markdown, h5py, grpcio, absl-py, wrapt, termcolor, tensorboard, opt-einsum, libclang, keras, google-pasta, gast, flatbuffers, astunparse, tensorflow
#   WARNING: The script markdown-it is installed in '/Users/nikitalondhe/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown_py is installed in '/Users/nikitalondhe/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tensorboard is installed in '/Users/nikitalondhe/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts import_pb_to_tensorboard, saved_model_cli, tensorboard, tf_upgrade_v2, tflite_convert and toco are installed in '/Users/nikitalondhe/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed absl-py-2.3.1 astunparse-1.6.3 flatbuffers-25.12.19 gast-0.7.0 google-pasta-0.2.0 grpcio-1.80.0 h5py-3.14.0 keras-3.10.0 libclang-18.1.1 markdown-3.9 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.5.4 namex-0.1.0 opt-einsum-3.4.0 optree-0.19.1 protobuf-6.33.6 rich-15.0.0 tensorboard-2.20.0 tensorboard-data-server-0.7.2 tensorflow-2.20.0 termcolor-3.1.0 werkzeug-3.1.8 wrapt-2.1.2
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# /Users/nikitalondhe/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
model=Sequential()
model.add(Dense(128,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(1,activation='linear'))

# %%
model.compile(optimizer='adam', loss= 'mae', metrics=['mse','mae'])

# %%
model.fit(x_train,y_train,epochs=50)
# Out:
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 785us/step - loss: 22.9245 - mae: 22.9245 - mse: 620.4500
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - loss: 19.6505 - mae: 19.6505 - mse: 474.3735
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step - loss: 16.1860 - mae: 16.1860 - mse: 346.6121
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - loss: 9.5177 - mae: 9.5177 - mse: 138.0731
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - loss: 6.7683 - mae: 6.7683 - mse: 75.6031
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - loss: 4.9685 - mae: 4.9685 - mse: 51.8688
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - loss: 3.8941 - mae: 3.8941 - mse: 31.9133
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - loss: 3.7759 - mae: 3.7759 - mse: 28.9683
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step - loss: 3.3718 - mae: 3.3718 - mse: 27.5249
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 3.1900 - mae: 3.1900 - mse: 22.6974
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step - loss: 3.3725 - mae: 3.3725 - mse: 28.9971
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - loss: 2.8237 - mae: 2.8237 - mse: 18.5383
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step - loss: 2.6837 - mae: 2.6837 - mse: 16.3979
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - loss: 2.6304 - mae: 2.6304 - mse: 17.6700
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - loss: 2.6530 - mae: 2.6530 - mse: 16.7494
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step - loss: 2.7422 - mae: 2.7422 - mse: 17.9846
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step - loss: 2.7112 - mae: 2.7112 - mse: 18.8086
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step - loss: 2.4411 - mae: 2.4411 - mse: 13.0486
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step - loss: 2.4351 - mae: 2.4351 - mse: 16.8113
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step - loss: 2.4371 - mae: 2.4371 - mse: 16.2932
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - loss: 2.5102 - mae: 2.5102 - mse: 15.1850
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - loss: 2.5166 - mae: 2.5166 - mse: 18.0067
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - loss: 2.3264 - mae: 2.3264 - mse: 14.0508
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step - loss: 2.8086 - mae: 2.8086 - mse: 23.3914
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step - loss: 2.4991 - mae: 2.4991 - mse: 17.1137
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - loss: 2.3140 - mae: 2.3140 - mse: 12.3323
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - loss: 2.2691 - mae: 2.2691 - mse: 14.6684
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step - loss: 2.5866 - mae: 2.5866 - mse: 17.6322
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - loss: 2.3509 - mae: 2.3509 - mse: 14.2925
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step - loss: 2.3846 - mae: 2.3846 - mse: 13.2225
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - loss: 2.2681 - mae: 2.2681 - mse: 16.4961
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - loss: 2.2490 - mae: 2.2490 - mse: 11.9992
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - loss: 2.1344 - mae: 2.1344 - mse: 11.0276
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step - loss: 2.4690 - mae: 2.4690 - mse: 16.4664
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 2.2212 - mae: 2.2212 - mse: 12.3035
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step - loss: 2.0620 - mae: 2.0620 - mse: 12.4281
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step - loss: 2.2747 - mae: 2.2747 - mse: 15.5790
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - loss: 1.9828 - mae: 1.9828 - mse: 10.4541
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - loss: 2.1072 - mae: 2.1072 - mse: 13.2548
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - loss: 2.0064 - mae: 2.0064 - mse: 13.5448
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - loss: 2.0160 - mae: 2.0160 - mse: 10.6594
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - loss: 2.1909 - mae: 2.1909 - mse: 14.7853
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step - loss: 1.9370 - mae: 1.9370 - mse: 10.3122
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - loss: 2.1837 - mae: 2.1837 - mse: 13.7824
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - loss: 2.0653 - mae: 2.0653 - mse: 11.3159
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - loss: 2.0259 - mae: 2.0259 - mse: 11.3812
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - loss: 1.9959 - mae: 1.9959 - mse: 12.4897
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - loss: 1.9872 - mae: 1.9872 - mse: 11.1971
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step - loss: 1.8660 - mae: 1.8660 - mse: 8.0489
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step - loss: 2.0409 - mae: 2.0409 - mse: 13.4938

# %%
metrics=model.evaluate(x_test,y_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0858 - mae: 2.0858 - mse: 7.1659

# %%
y_pred=model.predict(x_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
plt.plot(y_test.values[:50],label="Actual")
plt.plot(y_pred[:50],label="Predicted")
plt.title("Actual vs Predicted")
plt.legend()
plt.show()
